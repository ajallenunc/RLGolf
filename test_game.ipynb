# %%
from game_engine.card import Card
from game_engine.deck import Deck

# %%
# Test Card
c1 = Card('5','H')
print(f"Card: {c1.rank}{c1.suit}, Value: {c1.get_value()}")

c2 = Card('X','J')
print(f"Card: {c2.rank}{c2.suit}, Value: {c2.get_value()}")
# Out:
# Card: 5H, Value: 5
# Card: XJ, Value: -2

# %%
# --- Test Deck --- #
# Basic Deck
deck = Deck(num_decks=1,num_jokers=2)
print(f"Number of cards: {len(deck.cards)}")
for card in deck.cards: 
    print(f"{card.rank}{card.suit}")

# Shuffle deck 
deck.shuffle()
print(f"Number of cards: {len(deck.cards)}")
for card in deck.cards: 
    print(f"{card.rank}{card.suit}")
# Out:
# Number of cards: 54
# AH
# 2H
# 3H
# 4H
# 5H
# 6H
# 7H
# 8H
# 9H
# TH
# JH
# QH
# KH
# AD
# 2D
# 3D
# 4D
# 5D
# 6D
# 7D
# 8D
# 9D
# TD
# JD
# QD
# KD
# AC
# 2C
# 3C
# 4C
# 5C
# 6C
# 7C
# 8C
# 9C
# TC
# JC
# QC
# KC
# AS
# 2S
# 3S
# 4S
# 5S
# 6S
# 7S
# 8S
# 9S
# TS
# JS
# QS
# KS
# XJ
# XJ
# Number of cards: 54
# KS
# TH
# 5D
# AH
# TD
# AS
# 4C
# 3C
# 6H
# KD
# JD
# 5S
# 9D
# AD
# 6S
# 7S
# 4H
# JS
# AC
# 2H
# XJ
# JC
# 2C
# 8H
# 8S
# 9S
# 9C
# QS
# 6D
# 8C
# 3D
# 8D
# TS
# JH
# 2D
# QC
# 3H
# 4D
# 5H
# 7H
# 6C
# TC
# 5C
# KC
# 2S
# 3S
# QD
# 7C
# QH
# KH
# 4S
# 7D
# 9H
# XJ
